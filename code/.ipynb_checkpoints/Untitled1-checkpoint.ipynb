# %%
import pandas as pd
import numpy as np
import datetime
import wbdata

# %%
indicators = ['IC.BUS.DISC.XQ', 'IC.FRM.CMPU.ZS', 'IC.FRM.CORR.ZS', 'IC.FRM.INFM.ZS', 'IC.LGL.CRED.XQ',
              'IC.LGL.DURS', 'IC.TAX.GIFT.ZS', 'IQ.CPA.PROP.XQ', 'IQ.CPA.TRAN.XQ', 'NY.GDP.PCAP.CD', 
              'SE.PRM.PRSL.ZS', 'SI.POV.GINI', 'SL.UEM.TOTL.NE.ZS']
yearsToKeep = range(1990,2014)
years= (datetime.datetime(1990, 1, 1), datetime.datetime(2014, 12, 31))
df_procurements = pd.read_csv('../data_clean/Historic_and_Major_awards.csv')

# %%
country_names_map = pd.read_csv('../data_clean/clean_country_names.csv')

# %%
countries=[]
for c in country_names_map.clean.dropna():  
    countries.append(wbdata.search_countries(str(c), display=False))

# %%
countries_ids=[]
for c in countries:
    try:
        print(c[0]['id'])
        countries_ids.append(c[0]['id'])
    except:
        print 'no hubo'
# Out:
# AFG
# AFR
# no hubo
# ALB
# no hubo
# DZA
# no hubo
# ANR
# no hubo
# AGO
# no hubo
# ATG
# no hubo
# no hubo
# ARG
# no hubo
# ARM
# no hubo
# CEA
# no hubo
# AUS
# no hubo
# AUT
# no hubo
# AZE
# no hubo
# BGD
# no hubo
# BRB
# no hubo
# BLR
# no hubo
# BEL
# no hubo
# BLZ
# no hubo
# BEN
# no hubo
# BTN
# no hubo
# BOL
# no hubo
# BIH
# no hubo
# BWA
# no hubo
# BRA
# no hubo
# BGR
# no hubo
# BFA
# no hubo
# BDI
# no hubo
# KHM
# no hubo
# CMR
# no hubo
# CAN
# no hubo
# no hubo
# CLA
# no hubo
# no hubo
# CAF
# no hubo
# MCA
# no hubo
# CEU
# no hubo
# TCD
# no hubo
# CHL
# no hubo
# CHN
# no hubo
# COL
# no hubo
# COM
# no hubo
# no hubo
# no hubo
# CRI
# no hubo
# CIV
# no hubo
# HRV
# no hubo
# CYP
# no hubo
# CZE
# no hubo
# DJI
# no hubo
# DJI
# no hubo
# DMA
# no hubo
# DOM
# no hubo
# no hubo
# no hubo
# ECU
# no hubo
# EGY
# no hubo
# SLV
# no hubo
# GNQ
# no hubo
# ERI
# no hubo
# EST
# no hubo
# ETH
# no hubo
# CEU
# no hubo
# FRA
# no hubo
# FJI
# no hubo
# GAB
# no hubo
# GMB
# no hubo
# GEO
# no hubo
# DEU
# no hubo
# GHA
# no hubo
# GRD
# no hubo
# GTM
# no hubo
# GIN
# no hubo
# GNB
# no hubo
# GUY
# no hubo
# HTI
# no hubo
# HND
# no hubo
# HUN
# no hubo
# IND
# no hubo
# IND
# no hubo
# IDN
# no hubo
# IRN
# no hubo
# IRQ
# no hubo
# ISR
# no hubo
# ITA
# no hubo
# JAM
# no hubo
# JPN
# no hubo
# JOR
# no hubo
# KAZ
# no hubo
# KEN
# no hubo
# KIR
# no hubo
# no hubo
# no hubo
# KSV
# no hubo
# KWT
# no hubo
# KGZ
# no hubo
# no hubo
# CLA
# no hubo
# LVA
# no hubo
# LBN
# no hubo
# LSO
# no hubo
# LBR
# no hubo
# LTU
# no hubo
# MKD
# no hubo
# MDG
# no hubo
# MWI
# no hubo
# no hubo
# MKD
# no hubo
# CME
# no hubo
# IMN
# no hubo
# EGY
# no hubo
# HKG
# no hubo
# LIC
# no hubo
# HIC
# no hubo
# LDC
# no hubo
# TCA
# no hubo
# QAT
# no hubo
# CUW
# no hubo
# CLA
# no hubo
# CAA
# no hubo
# MLT
# no hubo
# MAC
# no hubo
# ANR
# no hubo
# CME
# no hubo
# MAF
# no hubo
# IRN
# no hubo
# ISL
# no hubo
# CAA
# no hubo
# NOC
# no hubo
# no hubo
# CSS
# no hubo
# NCL
# no hubo
# no hubo
# SXM
# no hubo
# GRC
# no hubo
# HPC
# no hubo

# %%
# Out:
# Afghanistan
# Africa
# Albania
# Algeria
# Andean Region
# Angola
# Antigua and Barbuda
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-f569c4653d14> in <module>()
#       1 for x in countries:
# ----> 2     print x[0]['name']
#
# IndexError: list index out of range

# %%
# Out:
# None

# %%
 countries = [i['id'] for i in wbdata.get_country(country_names_map.clean, display=False)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-278596936ff9> in <module>()
# ----> 1 countries = [i['id'] for i in wbdata.get_country(country_names_map.clean, display=False)]
#
# /Library/Python/2.7/site-packages/wbdata/api.pyc in get_country(country_id, incomelevel, lendingtype, display)
#     271     if display is None:
#     272         display = INTERACTIVE
# --> 273     if country_id:
#     274         if incomelevel or lendingtype:
#     275             raise ValueError("Can't specify country_id and aggregates")
#
# /Library/Python/2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     729         raise ValueError("The truth value of a {0} is ambiguous. "
#     730                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 731                          .format(self.__class__.__name__))
#     732
#     733     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
dat= pd.DataFrame()
for i in indicators:
    dat.append(wbdata.get_dataframe(i, country=u'all', data_date=years, convert_date=True))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-8275ab799cf1> in <module>()
#       1 dat= pd.DataFrame()
#       2 for i in indicators:
# ----> 3     dat.append(wbdata.get_dataframe(i, country=u'all',data_date=years, convert_date=True))
#
# <decorator-gen-125> in get_dataframe(indicators, country, data_date, convert_date, keep_levels)
#
# /Library/Python/2.7/site-packages/wbdata/api.pyc in uses_pandas(f, *args, **kwargs)
#      51     if not pd:
#      52         raise ValueError("Pandas must be installed to be used")
# ---> 53     return f(*args, **kwargs)
#      54
#      55
#
# /Library/Python/2.7/site-packages/wbdata/api.pyc in get_dataframe(indicators, country, data_date, convert_date, keep_levels)
#     414     to_df = {indicators[i]: get_data(i, country, data_date, convert_date,
#     415                                      pandas=True, keep_levels=keep_levels)
# --> 416              for i in indicators}
#     417     return pd.DataFrame(to_df)
#     418
#
# /Library/Python/2.7/site-packages/wbdata/api.pyc in <dictcomp>((i,))
#     414     to_df = {indicators[i]: get_data(i, country, data_date, convert_date,
#     415                                      pandas=True, keep_levels=keep_levels)
# --> 416              for i in indicators}
#     417     return pd.DataFrame(to_df)
#     418
#
# /Library/Python/2.7/site-packages/wbdata/api.pyc in get_data(indicator, country, data_date, convert_date, pandas, column_name, keep_levels)
#     165         else:
#     166             args.append(("date", data_date.strftime("%Y")))
# --> 167     data = fetcher.fetch(query_url, args)
#     168     if convert_date:
#     169         data = convert_dates_to_datetime(data)
#
# /Library/Python/2.7/site-packages/wbdata/fetcher.pyc in fetch(query_url, args, cached)
#     166         if response is None:
#     167             raise ValueError("Got no response")
# --> 168         results.extend(response[1])
#     169         this_page = response[0]['page']
#     170         pages = response[0]['pages']
#
# IndexError: list index out of range
